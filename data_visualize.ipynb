# %%
# import lib

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np;
import csv

#data path
processed_gene = r'C:\Users\vuduc\Differential_Expression_gene\i2rlab-rdea-40496506d299\data\GSE66099.csv'
# feature selection result
result = r'C:\Users\vuduc\Differential_Expression_gene\i2rlab-rdea-40496506d299\results\sepsis\fs_scores.csv'

top_gene = ['AREG',
       'DDIT4',
       'RHAG',
       'COX7B',
       'H1F0',
       'SLCO4A1',
       'ENPP2',
       'MT1F',
       'PRG2',
       'RGS1',
        'TNFAIP3',
            'STAT4',
            'MYL6B',
            'CD69',
            'SLC39A8'
           ]

# %%
# Read the file into a variable insurance_data

data = pd.read_csv(processed_gene)
result = pd.read_csv(result)

data.head();
lst=[None]*10604;
lst2=[None]*199;

i=0;
k=0;
while(k<199):
    lst2[k]=11000/2;
    k=k+1;
lst2[198]=11000;

dem1=0;
for line in data:
    dem=0
    parse = line.split();
    lst[i]=data[parse];
    i=i+1; 
j=0
for line in data:
    if(j>0 and j<=10596):
        dem=0
        parse = line.split();
        for ab in top_gene:
            if(parse[0]==ab):
                dem1=dem1+1;
                print(dem1)
                plt.plot(data[parse],color="yellow", label="bị bệnh");  
                dem=1;
                break;
    if(dem==0 and j%2==0):
        plt.plot(data[parse],color="gray");  
        j=j+1;
plt.title('Top 10 marker gene highest DEGs')

plt.xlabel('Patient ID')
plt.ylabel('Gene ID')
plt.show();

# %%
# plot 30 gene
data_30_gene = pd.read_csv(result)["feature"]
print(data_30_gene)

# %%
# Plot 10 gene
data = pd.read_csv(processed_gene)

list_of_column_names = list(data.columns)
# displaying the list of column names
# print('List of column names : ',
#       list_of_column_names)

#get 10 gene data and die data
gene_data = {
    'AREG':[],
   'DDIT4':[],
   'RHAG':[],
   'COX7B':[],
   'H1F0':[],
   'SLCO4A1':[],
   'ENPP2':[],
   'MT1F':[],
   'PRG2':[],
   'RGS1':[],
    'TNFAIP3':[],
    'STAT4':[],
    'MYL6B':[],
    'CD69':[],
    'SLC39A8':[]
}
for gene in top_gene:
    gene_data[gene].append(data[gene])
    
print(gene_data['AREG'])
colors = list("rgbcmyk")

l = [i for i in range(199)]
#all data
for gene in gene_data:
    plt.scatter(l, gene_data[gene],label=gene)
    plt.legend()
plt.show()

# each gene
for gene in gene_data:
#     print(sizeof(gene_data[gene])
    rgb = np.random.rand(3,)
    plt.figure(figsize=(5,5))
    plt.scatter(l, gene_data[gene],c=[rgb],label=gene)
    plt.legend()
plt.show()

# %%
# plot died patients gene

status = []
status.append(data["Died"])
vt = np.nonzero(status)

gene_data = {
    'AREG':[],
   'DDIT4':[],
   'RHAG':[],
   'COX7B':[],
   'H1F0':[],
   'SLCO4A1':[],
   'ENPP2':[],
   'MT1F':[],
   'PRG2':[],
   'RGS1':[],
    'TNFAIP3':[],
    'STAT4':[],
    'MYL6B':[],
    'CD69':[],
    'SLC39A8':[]
}

for gene in top_gene:
    temp = data[gene]
    for index, value in enumerate(temp):
        if index not in vt[1]:
            temp[index] = 0
    gene_data[gene].append(temp)
            

l = [i for i in range(199)]
# #all data
for gene in gene_data:
    plt.scatter(l, gene_data[gene],label=gene)
    plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('new_GSE66099_trans.csv')
data
# Out:
#           A2M     A4GNT      AAAS      AACS      AAK1      AAMP       AAT  \
# 0    2.243748  1.107010  3.587216  4.182330  6.447120  4.505749  2.092167
# 1    1.797216  1.266728  4.418469  5.010960  7.650317  4.419486  1.348086
# 2    2.402198  0.946330  3.842511  3.577492  6.975271  3.626157  1.960517
# 3    2.038175  1.134434  3.790135  4.081478  5.949536  4.077177  1.670026
# 4    2.290560  1.065330  4.904727  4.843061  7.153770  5.816867  1.638090
# ..        ...       ...       ...       ...       ...       ...       ...
# 194  1.774849  1.313065  3.640615  5.074639  7.932455  4.765025  1.432566
# 195  1.840260  1.486849  3.615629  5.316911  8.688786  4.527384  1.761043
# 196  2.147418  1.174694  4.133451  4.690899  6.840013  4.048171  1.649450
# 197  1.619393  1.420509  3.953219  6.060669  8.254296  5.424649  1.214202
# 198  2.257321  1.271273  4.216931  6.010624  7.794381  4.864222  1.775527
#
#          AARS      AATK      ABAT  ...    ZNF665    ZNF672    ZNF682  \
# ...

# %%
degs = pd.read_csv('heat_map_filter.csv')
degs_gene_id = degs["X"]
data_108_gens = data[degs_gene_id]
data[degs_gene_id].to_csv(r'C:\Users\vuduc\Differential_Expression_gene\i2rlab-rdea-40496506d299\data_108.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-5-63dfccb02316> in <module>
#       2 degs_gene_id = degs["X"]
#       3 data_108_gens = data[degs_gene_id]
# ----> 4 data[degs_gene_id].to_csv(r'C:\Users\vuduc\Differential_Expression_gene\i2rlab-rdea-40496506d299\data_108.csv', index = False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ...

# %%
fig, ax = plt.subplots(figsize=(30,20))
sns.heatmap(data_108_gens.corr(), center=0, cmap='Blues')
ax.set_title('Gene Attributes')
# Out:
# Text(0.5, 1.0, 'Gene Attributes')

# %%
# %matplotlib notebook 
from mpl_toolkits import mplot3d
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')


degs = pd.read_csv('data_plot_to_find_kernel.csv')


# degs_gene_id survival
# label = degs["Died"]
zdata = degs["SLC39A8"]
xdata = degs["RHAG"]
ydata = degs["DDIT4"]
#feature normalization
norm1 = np.linalg.norm(zdata)
norm2 = np.linalg.norm(xdata)
norm3 = np.linalg.norm(ydata)

z_data1 = (zdata/norm1)[0:28] 
x_data1 = (xdata/norm2)[0:28]
y_data1 = (ydata/norm3)[0:28]

z_data2 = (zdata/norm1)[28:] 
x_data2 = (xdata/norm2)[28:]
y_data2 = (ydata/norm3)[28:]

degs_gene_id.head()
ax.scatter3D(x_data1, y_data1, z_data1);
ax.scatter3D(x_data2, y_data2, z_data2);

# for angle in range(0, 360):
#     ax.view_init(120, angle)
#     plt.draw()
#     plt.pause(.001)
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
xdata[28:]
